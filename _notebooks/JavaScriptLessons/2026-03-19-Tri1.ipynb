# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# codemirror: true
# title: Trimester 1
# description: Trimester 1 work and highlights
# permalink: /js/tri1
# author: Aashi Hegu
# ---

# %% [markdown]
# <div style="background: linear-gradient(135deg, #f093fb 0%, #f5576c 100%); padding: 40px; border-radius: 15px; color: white; text-align: center; margin: 20px 0;">
#   <h1 style="color: white; margin: 0; font-size: 2.5em;">Trimester 1</h1>
#   <p style="font-size: 16px; margin: 10px 0 5px 0; opacity: 0.9;">Feb 25, 2025 &bull; 2 min read</p>
# </div>

# %% [markdown]
# <div style="display: flex; flex-wrap: wrap; gap: 12px; justify-content: center; margin: 25px 0;">
#   <a href="#achievements" style="background: linear-gradient(135deg, #667eea, #764ba2); color: white; padding: 10px 22px; border-radius: 25px; text-decoration: none; font-weight: bold; font-size: 14px;">Achievements</a>
#   <a href="#serving-a-team" style="background: linear-gradient(135deg, #f093fb, #f5576c); color: white; padding: 10px 22px; border-radius: 25px; text-decoration: none; font-weight: bold; font-size: 14px;">Serving a Team</a>
#   <a href="#learning-to-code" style="background: linear-gradient(135deg, #4facfe, #00f2fe); color: white; padding: 10px 22px; border-radius: 25px; text-decoration: none; font-weight: bold; font-size: 14px;">Learning to Code</a>
#   <a href="#tooling-and-setup" style="background: linear-gradient(135deg, #43e97b, #38f9d7); color: white; padding: 10px 22px; border-radius: 25px; text-decoration: none; font-weight: bold; font-size: 14px;">Tooling & Setup</a>
#   <a href="#javascript-lessons" style="background: linear-gradient(135deg, #fa709a, #fee140); color: white; padding: 10px 22px; border-radius: 25px; text-decoration: none; font-weight: bold; font-size: 14px;">JS Lessons</a>
#   <a href="#game-project" style="background: linear-gradient(135deg, #a18cd1, #fbc2eb); color: white; padding: 10px 22px; border-radius: 25px; text-decoration: none; font-weight: bold; font-size: 14px;">Game Project</a>
# </div>

# %% [markdown]
# <div id="achievements" style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); border-radius: 15px; padding: 25px; margin: 25px 0; color: white;">
#
# <h2 style="color: white; margin-top: 0;">Trimester in Review</h2>
#
# <p>This trimester went far beyond learning syntax or writing JavaScript. The biggest lesson was developing a <strong>coder's mindset</strong>&mdash;breaking problems into manageable steps, failing fast to learn quickly, and tracking down elusive syntax errors in large files. CSSE 1 taught me a set of habits and tools that I'll carry forward long after the class is over.</p>
#
# <h3 style="color: #fbc2eb;">Key Takeaways</h3>
#
# <table style="width: 100%; border-collapse: collapse; color: white; margin-top: 10px;">
# <thead>
# <tr>
# <th style="border: 1px solid rgba(255,255,255,0.3); padding: 10px; text-align: left; background: rgba(255,255,255,0.1);">Area</th>
# <th style="border: 1px solid rgba(255,255,255,0.3); padding: 10px; text-align: left; background: rgba(255,255,255,0.1);">What I Learned</th>
# </tr>
# </thead>
# <tbody>
# <tr><td style="border: 1px solid rgba(255,255,255,0.2); padding: 10px;">Developer Tools</td><td style="border: 1px solid rgba(255,255,255,0.2); padding: 10px;">Worked comfortably with an operating system and developer toolchain</td></tr>
# <tr><td style="border: 1px solid rgba(255,255,255,0.2); padding: 10px;">Teamwork</td><td style="border: 1px solid rgba(255,255,255,0.2); padding: 10px;">Balanced multiple roles: teacher, collaborator, and learner</td></tr>
# <tr><td style="border: 1px solid rgba(255,255,255,0.2); padding: 10px;">Mindset</td><td style="border: 1px solid rgba(255,255,255,0.2); padding: 10px;">Embraced patience and incremental progress instead of rushing to finish</td></tr>
# <tr><td style="border: 1px solid rgba(255,255,255,0.2); padding: 10px;">Planning</td><td style="border: 1px solid rgba(255,255,255,0.2); padding: 10px;">Planned projects more realistically&mdash;and learned from the times I didn't</td></tr>
# </tbody>
# </table>
#
# <p style="margin-top: 15px; font-style: italic; opacity: 0.9;">Below are some highlights from the journey.</p>
#
# </div>

# %% [markdown]
# <div id="serving-a-team" style="background: linear-gradient(135deg, #f093fb 0%, #f5576c 100%); border-radius: 15px; padding: 25px; margin: 25px 0; color: white;">
#
# <h2 style="color: white; margin-top: 0;">Serving a Team</h2>
#
# <p>I wore many hats this trimester: <strong>student and teacher</strong>. While I've had similar roles before, CSSE was the most sustained and in-depth experience yet.</p>
#
# <div style="display: grid; grid-template-columns: repeat(auto-fit, minmax(250px, 1fr)); gap: 12px; margin: 15px 0;">
#
# <div style="background: rgba(255,255,255,0.15); border-radius: 10px; padding: 15px;">
# <strong>Presenting</strong><br/>Presented technical material to beginners and distilled complex ideas
# </div>
#
# <div style="background: rgba(255,255,255,0.15); border-radius: 10px; padding: 15px;">
# <strong>Building</strong><br/>Built interactive homework assignments to gauge understanding
# </div>
#
# <div style="background: rgba(255,255,255,0.15); border-radius: 10px; padding: 15px;">
# <strong>Supporting</strong><br/>Supported classmates who were hesitant to ask questions
# </div>
#
# <div style="background: rgba(255,255,255,0.15); border-radius: 10px; padding: 15px;">
# <strong>Communicating</strong><br/>Communicated effectively with instructors about their goals and how I could help achieve them
# </div>
#
# </div>
#
# <h3 style="color: white;">Team Dynamics</h3>
#
# <ul>
# <li>I led our group as the teacher until the game project, where I shifted to coding</li>
# <li>Guided teammates through challenges despite varying skill levels and motivations</li>
# <li>Coordinated across subgroups (e.g. spriting vs. programming) to keep everyone moving forward</li>
# </ul>
#
# <div style="background: rgba(255,255,255,0.2); border-radius: 10px; padding: 15px; margin-top: 15px; text-align: center;">
# <strong style="font-size: 1.1em;">Proudest Achievement</strong><br/>
# Fostering connections in my team and collaborating on fun hacks and a working game
# </div>
#
# </div>

# %% [markdown]
# <div id="learning-to-code" style="background: linear-gradient(135deg, #4facfe 0%, #00f2fe 100%); border-radius: 15px; padding: 25px; margin: 25px 0; color: white;">
#
# <h2 style="color: white; margin-top: 0;">Learning to Code</h2>
#
# <p>Coding itself was a roller-coaster that paid off in surprising ways.</p>
#
# </div>

# %% [markdown]
# <div id="tooling-and-setup" style="background: linear-gradient(135deg, #43e97b 0%, #38f9d7 100%); border-radius: 15px; padding: 25px; margin: 25px 0; color: white;">
#
# <h2 style="color: white; margin-top: 0;">Tooling & Setup</h2>
#
# <p>Setting up the environment was the hardest part&mdash;there was always something new to master.</p>
#
# <div style="display: flex; flex-wrap: wrap; gap: 10px; margin-top: 15px;">
# <div style="background: rgba(255,255,255,0.2); border-radius: 8px; padding: 12px 18px; font-weight: bold;">GitHub</div>
# <div style="background: rgba(255,255,255,0.2); border-radius: 8px; padding: 12px 18px; font-weight: bold;">VS Code</div>
# <div style="background: rgba(255,255,255,0.2); border-radius: 8px; padding: 12px 18px; font-weight: bold;">Terminal</div>
# <div style="background: rgba(255,255,255,0.2); border-radius: 8px; padding: 12px 18px; font-weight: bold;">Git</div>
# </div>
#
# <p style="margin-top: 15px;">Created and managed GitHub repositories, using VS Code fluently.</p>
#
# </div>

# %% [markdown]
# <div id="javascript-lessons" style="background: linear-gradient(135deg, #fa709a 0%, #fee140 100%); border-radius: 15px; padding: 25px; margin: 25px 0; color: white;">
#
# <h2 style="color: white; margin-top: 0;">JavaScript Lessons & Teaching</h2>
#
# <p>The unit on JavaScript stretched me, especially when co-designing lessons.</p>
#
# <table style="width: 100%; border-collapse: collapse; color: white; margin-top: 15px;">
# <thead>
# <tr>
# <th style="border: 1px solid rgba(255,255,255,0.3); padding: 10px; text-align: left; background: rgba(255,255,255,0.15);">Topic</th>
# <th style="border: 1px solid rgba(255,255,255,0.3); padding: 10px; text-align: left; background: rgba(255,255,255,0.15);">What I Did</th>
# </tr>
# </thead>
# <tbody>
# <tr><td style="border: 1px solid rgba(255,255,255,0.2); padding: 10px;">Booleans</td><td style="border: 1px solid rgba(255,255,255,0.2); padding: 10px;">Made a boolean lesson</td></tr>
# <tr><td style="border: 1px solid rgba(255,255,255,0.2); padding: 10px;">JSON, Math, Strings</td><td style="border: 1px solid rgba(255,255,255,0.2); padding: 10px;">Gained familiarity with JSON, math expressions, strings, and more</td></tr>
# <tr><td style="border: 1px solid rgba(255,255,255,0.2); padding: 10px;">Foundation</td><td style="border: 1px solid rgba(255,255,255,0.2); padding: 10px;">Built a stronger foundation that made the game-development unit easier</td></tr>
# </tbody>
# </table>
#
# </div>

# %% [markdown]
# <div id="game-project" style="background: linear-gradient(135deg, #a18cd1 0%, #fbc2eb 100%); border-radius: 15px; padding: 25px; margin: 25px 0; color: white;">
#
# <h2 style="color: white; margin-top: 0;">Class Game Project</h2>
#
# <p>During the game, I mostly answered questions at the tables and led the spriting team.</p>
#
# <div style="display: grid; grid-template-columns: repeat(auto-fit, minmax(220px, 1fr)); gap: 12px; margin: 15px 0;">
#
# <div style="background: rgba(255,255,255,0.2); border-radius: 10px; padding: 15px; text-align: center;">
# <div style="font-size: 2em; margin-bottom: 5px;">&#127912;</div>
# <strong>Main Character</strong><br/>Designed the main character and made backgrounds
# </div>
#
# <div style="background: rgba(255,255,255,0.2); border-radius: 10px; padding: 15px; text-align: center;">
# <div style="font-size: 2em; margin-bottom: 5px;">&#128123;</div>
# <strong>Boss Level</strong><br/>Coded the boss level
# </div>
#
# <div style="background: rgba(255,255,255,0.2); border-radius: 10px; padding: 15px; text-align: center;">
# <div style="font-size: 2em; margin-bottom: 5px;">&#128260;</div>
# <strong>Adaptability</strong><br/>Adapted as the original vision shifted, trimming features and compromising to reach a finished product
# </div>
#
# </div>
#
# </div>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #0f3460 0%, #16213e 100%); border-radius: 15px; padding: 30px; margin: 25px 0; color: white; text-align: center;">
#
# <h2 style="color: #fbc2eb; margin-top: 0;">Looking Back</h2>
#
# <p style="font-size: 1.1em; max-width: 600px; margin: 0 auto;">This trimester has been a rich blend of technical growth, teamwork, and self-reflection. I've built skills, confidence, and relationships that extend far beyond the classroom.</p>
#
# <div style="margin-top: 20px;">
# <a href="{{site.baseurl}}/js/cs111" style="display: inline-block; background: linear-gradient(135deg, #f093fb, #f5576c); color: white; padding: 12px 28px; border-radius: 25px; text-decoration: none; font-weight: bold; margin: 5px;">Back to CS111</a>
# <a href="{{site.baseurl}}/js/tri2" style="display: inline-block; background: linear-gradient(135deg, #4facfe, #00f2fe); color: white; padding: 12px 28px; border-radius: 25px; text-decoration: none; font-weight: bold; margin: 5px;">View Tri 2 &rarr;</a>
# </div>
#
# </div>
