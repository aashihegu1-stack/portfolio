# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# codemirror: true
# title: CS111 Project
# description: Comprehensive JavaScript project covering all CS111 rubric topics
# permalink: /js/cs111
# author: Aashi Hegu
# ---

# %% [markdown]
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); padding: 30px; border-radius: 15px; color: white; text-align: center; margin: 30px 0;">
#   <h1 style="color: white; margin: 0;">🖥️ Computer Science 1-2</h1>
#   <p style="font-size: 16px;">Trimester Highlights &amp; Portfolio</p>
# </div>

# %% [markdown]
# <div style="background: #0f3460; border-radius: 12px; padding: 20px; margin-bottom: 20px;">
#   <h2 style="color: white; margin-top: 0;">🗂️ Rubric Coverage Map</h2>
#   <table style="width: 100%; border-collapse: collapse; color: white;">
#     <thead>
#       <tr>
#         <th style="border: 1px solid rgba(255,255,255,0.3); padding: 10px; text-align: left; background: rgba(255,255,255,0.1);">CS111 Rubric Topic</th>
#         <th style="border: 1px solid rgba(255,255,255,0.3); padding: 10px; text-align: left; background: rgba(255,255,255,0.1);">Covered By</th>
#         <th style="border: 1px solid rgba(255,255,255,0.3); padding: 10px; text-align: left; background: rgba(255,255,255,0.1);">Status</th>
#       </tr>
#     </thead>
#     <tbody>
#       <tr><td style="border: 1px solid rgba(255,255,255,0.2); padding: 10px;">🔢 Data Types — Numbers</td><td style="border: 1px solid rgba(255,255,255,0.2); padding: 10px;">Variables, Math Expressions</td><td style="border: 1px solid rgba(255,255,255,0.2); padding: 10px;">✅</td></tr>
#       <tr><td style="border: 1px solid rgba(255,255,255,0.2); padding: 10px;">🔤 Data Types — Strings</td><td style="border: 1px solid rgba(255,255,255,0.2); padding: 10px;">Strings Homework</td><td style="border: 1px solid rgba(255,255,255,0.2); padding: 10px;">✅</td></tr>
#       <tr><td style="border: 1px solid rgba(255,255,255,0.2); padding: 10px;">✅ Data Types — Booleans</td><td style="border: 1px solid rgba(255,255,255,0.2); padding: 10px;">Boolean Homework</td><td style="border: 1px solid rgba(255,255,255,0.2); padding: 10px;">✅</td></tr>
#       <tr><td style="border: 1px solid rgba(255,255,255,0.2); padding: 10px;">📦 Data Types — Arrays</td><td style="border: 1px solid rgba(255,255,255,0.2); padding: 10px;">Arrays, Array Hack, Data Abstraction</td><td style="border: 1px solid rgba(255,255,255,0.2); padding: 10px;">✅</td></tr>
#       <tr><td style="border: 1px solid rgba(255,255,255,0.2); padding: 10px;">🗃️ Data Types — JSON Objects</td><td style="border: 1px solid rgba(255,255,255,0.2); padding: 10px;">Data Abstraction</td><td style="border: 1px solid rgba(255,255,255,0.2); padding: 10px;">✅</td></tr>
#       <tr><td style="border: 1px solid rgba(255,255,255,0.2); padding: 10px;">➕ Operators — Mathematical</td><td style="border: 1px solid rgba(255,255,255,0.2); padding: 10px;">Math Expressions</td><td style="border: 1px solid rgba(255,255,255,0.2); padding: 10px;">✅</td></tr>
#       <tr><td style="border: 1px solid rgba(255,255,255,0.2); padding: 10px;">🔗 Operators — String</td><td style="border: 1px solid rgba(255,255,255,0.2); padding: 10px;">Strings Homework</td><td style="border: 1px solid rgba(255,255,255,0.2); padding: 10px;">✅</td></tr>
#       <tr><td style="border: 1px solid rgba(255,255,255,0.2); padding: 10px;">⚖️ Operators — Boolean</td><td style="border: 1px solid rgba(255,255,255,0.2); padding: 10px;">Boolean Homework</td><td style="border: 1px solid rgba(255,255,255,0.2); padding: 10px;">✅</td></tr>
#       <tr><td style="border: 1px solid rgba(255,255,255,0.2); padding: 10px;">🔁 Control Structures — Iteration</td><td style="border: 1px solid rgba(255,255,255,0.2); padding: 10px;">Iteration Homework</td><td style="border: 1px solid rgba(255,255,255,0.2); padding: 10px;">✅</td></tr>
#       <tr><td style="border: 1px solid rgba(255,255,255,0.2); padding: 10px;">🔀 Control Structures — Conditions</td><td style="border: 1px solid rgba(255,255,255,0.2); padding: 10px;">Boolean, Functions</td><td style="border: 1px solid rgba(255,255,255,0.2); padding: 10px;">✅</td></tr>
#       <tr><td style="border: 1px solid rgba(255,255,255,0.2); padding: 10px;">🏗️ Classes & OOP</td><td style="border: 1px solid rgba(255,255,255,0.2); padding: 10px;">Classes & Constructors, Classes & Variables</td><td style="border: 1px solid rgba(255,255,255,0.2); padding: 10px;">✅</td></tr>
#       <tr><td style="border: 1px solid rgba(255,255,255,0.2); padding: 10px;">⚙️ Methods & Parameters</td><td style="border: 1px solid rgba(255,255,255,0.2); padding: 10px;">Functions, Classes & Constructors</td><td style="border: 1px solid rgba(255,255,255,0.2); padding: 10px;">✅</td></tr>
#     </tbody>
#   </table>
# </div>

# %% [markdown]
# <div style="display: flex; gap: 15px; flex-wrap: wrap; margin-bottom: 20px;">
#
# <div style="flex: 1; min-width: 280px; background: linear-gradient(135deg, #f093fb 0%, #f5576c 100%); border-radius: 12px; padding: 20px; color: white;">
#   <h3 style="color: white; margin-top: 0;">📘 Trimester 1</h3>
#   <ul style="list-style: none; padding: 0;">
#     <li>🔧 Tools &amp; Setup</li>
#     <li>🌐 HTML/CSS Fundamentals</li>
#     <li>🎮 Sprites/backgrounds</li>
#     <li>🧩 Game Development</li>
#     <li>📦 Operators</li>
#   </ul>
#   <a href="/portfolio/js/tri1" style="display: inline-block; background: white; color: #f5576c; border: none; padding: 10px 20px; border-radius: 8px; font-weight: bold; cursor: pointer; margin-top: 10px; text-decoration: none;">📂 View Tri 1 Work</a>
# </div>
#
# <div style="flex: 1; min-width: 280px; background: linear-gradient(135deg, #4facfe 0%, #00f2fe 100%); border-radius: 12px; padding: 20px; color: white;">
#   <h3 style="color: white; margin-top: 0;">📗 Trimester 2</h3>
#   <ul style="list-style: none; padding: 0;">
#     <li>🔢 Game builder &amp; engine</li>
#     <li>⚙️ Functions &amp; Methods</li>
#     <li>🚀 Full Stack Projects</li>
#   </ul>
#   <a href="/portfolio/js/tri2" style="display: inline-block; background: white; color: #4facfe; border: none; padding: 10px 20px; border-radius: 8px; font-weight: bold; cursor: pointer; margin-top: 10px; text-decoration: none;">📂 View Tri 2 Work</a>
# </div>
#
# </div>
