# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# codemirror: true
# title: CS111 Project
# description: Comprehensive JavaScript project covering all CS111 rubric topics
# permalink: /js/cs111
# author: Aashi Hegu
# ---

# %% [markdown]
# # **CS111**

# %% [markdown]
# <div style="color: white; padding: 10px;">
#
# **Name:** <span style="color: red;">Aashi Hegu</span>
# **Grade:** <span style="color: red;">9th</span>
# **School:** <span style="color: red;">Del Norte</span>
# **Class:** <span style="color: red;">Computer Science 2</span>
# **Project:** <span style="color: red;">CS111</span>
#
# </div>

# %% [markdown]
# <div style="background: #0f3460; border-radius: 12px; padding: 20px; margin-bottom: 20px; color: white;">
#
# <h2>🗂️ Rubric Coverage Map</h2>
#
# <table style="width: 100%; border-collapse: collapse; color: white;">
# <thead>
# <tr>
# <th style="border: 1px solid #555; padding: 8px; text-align: left;">CS111 Rubric Topic</th>
# <th style="border: 1px solid #555; padding: 8px; text-align: left;">Covered By</th>
# <th style="border: 1px solid #555; padding: 8px; text-align: left;">Status</th>
# </tr>
# </thead>
# <tbody>
# <tr><td style="border: 1px solid #555; padding: 8px;">🔢 Data Types — Numbers</td><td style="border: 1px solid #555; padding: 8px;">Variables, Math Expressions</td><td style="border: 1px solid #555; padding: 8px;">✅</td></tr>
# <tr><td style="border: 1px solid #555; padding: 8px;">🔤 Data Types — Strings</td><td style="border: 1px solid #555; padding: 8px;">Strings Homework</td><td style="border: 1px solid #555; padding: 8px;">✅</td></tr>
# <tr><td style="border: 1px solid #555; padding: 8px;">✅ Data Types — Booleans</td><td style="border: 1px solid #555; padding: 8px;">Boolean Homework</td><td style="border: 1px solid #555; padding: 8px;">✅</td></tr>
# <tr><td style="border: 1px solid #555; padding: 8px;">📦 Data Types — Arrays</td><td style="border: 1px solid #555; padding: 8px;">Arrays, Array Hack, Data Abstraction</td><td style="border: 1px solid #555; padding: 8px;">✅</td></tr>
# <tr><td style="border: 1px solid #555; padding: 8px;">🗃️ Data Types — JSON Objects</td><td style="border: 1px solid #555; padding: 8px;">Data Abstraction</td><td style="border: 1px solid #555; padding: 8px;">✅</td></tr>
# <tr><td style="border: 1px solid #555; padding: 8px;">➕ Operators — Mathematical</td><td style="border: 1px solid #555; padding: 8px;">Math Expressions</td><td style="border: 1px solid #555; padding: 8px;">✅</td></tr>
# <tr><td style="border: 1px solid #555; padding: 8px;">🔗 Operators — String</td><td style="border: 1px solid #555; padding: 8px;">Strings Homework</td><td style="border: 1px solid #555; padding: 8px;">✅</td></tr>
# <tr><td style="border: 1px solid #555; padding: 8px;">⚖️ Operators — Boolean</td><td style="border: 1px solid #555; padding: 8px;">Boolean Homework</td><td style="border: 1px solid #555; padding: 8px;">✅</td></tr>
# <tr><td style="border: 1px solid #555; padding: 8px;">🔁 Control Structures — Iteration</td><td style="border: 1px solid #555; padding: 8px;">Iteration Homework</td><td style="border: 1px solid #555; padding: 8px;">✅</td></tr>
# <tr><td style="border: 1px solid #555; padding: 8px;">🔀 Control Structures — Conditions</td><td style="border: 1px solid #555; padding: 8px;">Boolean, Functions</td><td style="border: 1px solid #555; padding: 8px;">✅</td></tr>
# <tr><td style="border: 1px solid #555; padding: 8px;">🏗️ Classes & OOP</td><td style="border: 1px solid #555; padding: 8px;">Classes & Constructors, Classes & Variables</td><td style="border: 1px solid #555; padding: 8px;">✅</td></tr>
# <tr><td style="border: 1px solid #555; padding: 8px;">⚙️ Methods & Parameters</td><td style="border: 1px solid #555; padding: 8px;">Functions, Classes & Constructors</td><td style="border: 1px solid #555; padding: 8px;">✅</td></tr>
# </tbody>
# </table>
#
# </div>

# %% [markdown]
# ---
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); padding: 30px; border-radius: 15px; color: white; text-align: center; margin: 30px 0;">
#   <h1 style="color: white; margin: 0;">🖥️ Computer Science 1-2</h1>
#   <p style="font-size: 16px;">Trimester Highlights & Portfolio</p>
# </div>

# %% [markdown]
# <div style="display: flex; gap: 15px; flex-wrap: wrap; margin-bottom: 20px;">
#
# <div style="flex: 1; min-width: 280px; background: linear-gradient(135deg, #f093fb 0%, #f5576c 100%); border-radius: 12px; padding: 20px; color: white;">
#
# <h3>📘 Trimester 1</h3>
#
# <p><strong>Coming soon!</strong> This section will cover:</p>
# <ul>
# <li>🔧 Tools &amp; Setup</li>
# <li>🌐 HTML/CSS Fundamentals</li>
# <li>📜 JavaScript Basics</li>
# <li>🎮 Sprite Animations</li>
# <li>🧩 Game Development</li>
# <li>📦 Version Control with Git</li>
# </ul>
#
# <button style="background: white; color: #f5576c; border: none; padding: 10px 20px; border-radius: 8px; font-weight: bold; cursor: pointer; margin-top: 10px;">📂 View Tri 1 Work</button>
#
# </div>
#
# <div style="flex: 1; min-width: 280px; background: linear-gradient(135deg, #4facfe 0%, #00f2fe 100%); border-radius: 12px; padding: 20px; color: white;">
#
# <h3>📗 Trimester 2</h3>
#
# <p><strong>Coming soon!</strong> This section will cover:</p>
# <ul>
# <li>🔢 Data Types Deep Dive</li>
# <li>🔁 Loops &amp; Iteration</li>
# <li>🏗️ Classes &amp; OOP</li>
# <li>🗃️ Data Abstraction</li>
# <li>⚙️ Functions &amp; Methods</li>
# <li>🚀 Full Stack Projects</li>
# </ul>
#
# <button style="background: white; color: #4facfe; border: none; padding: 10px 20px; border-radius: 8px; font-weight: bold; cursor: pointer; margin-top: 10px;">📂 View Tri 2 Work</button>
#
# </div>
#
# </div>

# %% [markdown]
# ---
#
# <div style="background: linear-gradient(135deg, #11998e 0%, #38ef7d 100%); padding: 20px; border-radius: 15px; text-align: center; margin-top: 20px;">
#   <h2 style="color: white; margin: 0;">🎉 CS111 Project Complete!</h2>
#   <p style="color: white; font-size: 16px;">By Aashi Hegu | Grade 9 | Del Norte | Computer Science 2</p>
#   <p style="color: white;">✅ All 12 rubric topics covered!</p>
# </div>
